# %% [markdown]
# # Overview
#
# ## Fluids:
#
# * mapping channel flow
# * surface Navier Stokes
# * real-time change of geometry
#
# ## Elasticity:
#
# * Rigid bodies (spinning top)
# * rotor
#
# ## Pullback of tensors
# * all good for alternating forms
# * geometry-free operators and bilinear-forms
# * additional derivatives (Hessian) - that's life
# * basis from barycentric coordinates
# * HHJ on deformed quads
# * Mapping of HCT / JKM elements
